# %%
print("first commit")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks/DeepLearningAssignment
# Out:
# /content/drive/My Drive/Colab Notebooks/DeepLearningAssignment

# %%
# !git config --global user.email "starirene9@gmail.com"
# !git config --global user.name "starire"
